# %%
from scipy import stats
from scipy . stats import norm

# %%
df = 300 # grados de libertad
alfa =0.05

t = stats . t ( df )

t_obs = t . ppf ( alfa )
print ( " El valor de t para una probabilidad acumulada a izquierda de " , alfa , "es de : " , t_obs )

# %%
# Valor de t para probabilidad acumulada a izquierda
t_obs = -1.96
df = 300 # grados de libertad

t = stats . t ( df )

alfa = t . sf ( t_obs )

print ( " La probabilidad acumulada a izquierda de un valor t " , t_obs , " es de : ",1 - alfa )
